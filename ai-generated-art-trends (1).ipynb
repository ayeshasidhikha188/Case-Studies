# %%
# Dataset link below.

# %%
https://www.kaggle.com/datasets/waqi786/ai-generated-art-trends

# %%
df=pd.read_csv(r"C:\Users\mdimr\Downloads\archive (3)\ai_generated_art_trends_2024.csv")

# %%
import pandas as pd

# %%
df
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001            DALL-E     Conceptual    2023-03-11        Collage
# 1     ART-00002      AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 3     ART-00004        ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 4     ART-00005            DALL-E     Surrealism    2022-12-05        Collage
# ...         ...               ...            ...           ...            ...
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22      Oil Paint
# 9996  ART-09997         RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
# 9998  ART-09999  GenerativeGenius         Cubism    2022-10-04  Acrylic Paint
# 9999  ART-10000  GenerativeGenius       Abstract    2022-12-07  Pencil Sketch
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0       GANPaint           1604.25  South America       Urban   Instagram
# 1     MidJourney           4162.12  North America    Abstract    Dribbble
# 2       GANPaint           2989.38         Europe   Mythology      Reddit
# 3     ArtBreeder           2985.97         Europe  Still Life      Tumblr
# 4      DeepDream           2035.18           Asia  Conceptual  DeviantArt
# ...          ...               ...            ...         ...         ...
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
# 9998    GANPaint           2229.60         Africa    Portrait  DeviantArt
# 9999   DeepDream           3815.99           Asia       Urban     Twitter
#
#                                             Description  \
# 0     A mesmerizing piece of art that blends traditi...
# 1     A mesmerizing piece of art that blends traditi...
# 2     A mesmerizing piece of art that blends traditi...
# 3     A mesmerizing piece of art that blends traditi...
# 4     A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9995  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
# 9998  A mesmerizing piece of art that blends traditi...
# 9999  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 0     https://example.com/artwork/00001.jpg
# 1     https://example.com/artwork/00002.jpg
# 2     https://example.com/artwork/00003.jpg
# 3     https://example.com/artwork/00004.jpg
# 4     https://example.com/artwork/00005.jpg
# ...                                     ...
# 9995  https://example.com/artwork/09996.jpg
# 9996  https://example.com/artwork/09997.jpg
# 9997  https://example.com/artwork/09998.jpg
# 9998  https://example.com/artwork/09999.jpg
# 9999  https://example.com/artwork/10000.jpg
#
# [10000 rows x 12 columns]

# %% [markdown]
# ### 1.What are the different art styles present in the dataset?

# %%
df["Art_Style"].unique()
# Out:
# array(['Conceptual', 'Futurism', 'Impressionism', 'Surrealism',
#        'Abstract', 'Realism', 'Minimalism', 'Pop Art', 'Cubism',
#        'Expressionism'], dtype=object)

# %% [markdown]
# ### 2.How many artworks were created in the year 2023?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artwork_ID        10000 non-null  object
#  1   Artist_Name       10000 non-null  object
#  2   Art_Style         10000 non-null  object
#  3   Creation_Date     10000 non-null  object
#  4   Medium            10000 non-null  object
#  5   Tools_Used        10000 non-null  object
#  6   Popularity_Score  10000 non-null  float64
#  7   Region            10000 non-null  object
#  8   Art_Genre         10000 non-null  object
#  9   Platform          10000 non-null  object
#  10  Description       10000 non-null  object
#  11  Image_URL         10000 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 937.6+ KB

# %%
df["Creation_Date"]=pd.to_datetime(df["Creation_Date"])

# %%
df["year"]=df["Creation_Date"].dt.year

# %%
df["year"].value_counts()
# Out:
# 2023    5079
# 2024    3312
# 2022    1609
# Name: year, dtype: int64

# %% [markdown]
# ### 3.Find all artworks that have a "Popularity_Score" greater than 4000.

# %%
pop=df[df['Popularity_Score']>4000]
pop
# Out:
#      Artwork_ID   Artist_Name      Art_Style Creation_Date         Medium  \
# 1     ART-00002  AbstractoBot       Futurism    2022-11-27      Oil Paint
# 5     ART-00006        DALL-E       Futurism    2022-12-13      Oil Paint
# 7     ART-00008        DALL-E  Impressionism    2024-07-22       3D Model
# 19    ART-00020     PicassoAI     Minimalism    2022-10-07       3D Model
# 35    ART-00036       Vincent     Conceptual    2023-09-03  Pencil Sketch
# ...         ...           ...            ...           ...            ...
# 9972  ART-09973        DALL-E  Expressionism    2024-01-19  Acrylic Paint
# 9975  ART-09976    ArtBreeder  Impressionism    2023-04-03  Pencil Sketch
# 9978  ART-09979  AbstractoBot       Futurism    2024-03-07        Collage
# 9981  ART-09982        DALL-E     Minimalism    2023-06-13     Watercolor
# 9996  ART-09997     RenoirBot        Pop Art    2023-04-05  Acrylic Paint
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 1     MidJourney           4162.12  North America    Abstract    Dribbble
# 5         DALL-E           4535.59           Asia    Abstract   Instagram
# 7      DeepDream           4989.07           Asia   Landscape   Instagram
# 19      GANPaint           4899.42         Africa  Conceptual     Behance
# 35    MidJourney           4992.66         Europe      Nature  DeviantArt
# ...          ...               ...            ...         ...         ...
# 9972   DeepDream           4277.85  North America     Fantasy   Instagram
# 9975  ArtBreeder           4273.38         Europe    Portrait     Twitter
# 9978  ArtBreeder           4487.09         Europe   Mythology     Twitter
# 9981    GANPaint           4045.10         Europe  Still Life  ArtStation
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
#
#                                             Description  \
# 1     A mesmerizing piece of art that blends traditi...
# 5     A mesmerizing piece of art that blends traditi...
# 7     A mesmerizing piece of art that blends traditi...
# 19    A mesmerizing piece of art that blends traditi...
# 35    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9972  A mesmerizing piece of art that blends traditi...
# 9975  A mesmerizing piece of art that blends traditi...
# 9978  A mesmerizing piece of art that blends traditi...
# 9981  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 1     https://example.com/artwork/00002.jpg
# 5     https://example.com/artwork/00006.jpg
# 7     https://example.com/artwork/00008.jpg
# 19    https://example.com/artwork/00020.jpg
# 35    https://example.com/artwork/00036.jpg
# ...                                     ...
# 9972  https://example.com/artwork/09973.jpg
# 9975  https://example.com/artwork/09976.jpg
# 9978  https://example.com/artwork/09979.jpg
# 9981  https://example.com/artwork/09982.jpg
# 9996  https://example.com/artwork/09997.jpg
#
# [2020 rows x 12 columns]

# %%
pop.count()
# Out:
# Artwork_ID          2020
# Artist_Name         2020
# Art_Style           2020
# Creation_Date       2020
# Medium              2020
# Tools_Used          2020
# Popularity_Score    2020
# Region              2020
# Art_Genre           2020
# Platform            2020
# Description         2020
# Image_URL           2020
# dtype: int64

# %% [markdown]
# ### 4.Calculate the total number of artworks for each "Region".

# %%
df['Region'].value_counts()
# Out:
# South America    1728
# Europe           1700
# North America    1659
# Asia             1648
# Africa           1636
# Oceania          1629
# Name: Region, dtype: int64

# %% [markdown]
# ### 5.What is the average "Popularity_Score" of artworks in the "Futurism" art style?

# %%
df[df['Art_Style']=='Futurism']['Popularity_Score'].mean()
# Out:
# 2522.9186909448817

# %% [markdown]
# ### 6.Sort the artworks by "Popularity_Score" and display the top 10 most popular artworks.

# %%
df.sort_values(by='Popularity_Score').head(10)
# Out:
#      Artwork_ID    Artist_Name      Art_Style Creation_Date         Medium  \
# 909   ART-00910      DeepDream        Realism    2023-11-01            Ink
# 1833  ART-01834  NeoSurrealist       Futurism    2023-06-15      Oil Paint
# 6632  ART-06633      DeepDream       Futurism    2024-03-10  Acrylic Paint
# 7673  ART-07674      RenoirBot     Surrealism    2023-12-07       Charcoal
# 7472  ART-07473         DALL-E         Cubism    2024-05-27  Acrylic Paint
# 3840  ART-03841        Vincent  Impressionism    2024-05-07      Oil Paint
# 7232  ART-07233    AIArtist123       Abstract    2023-11-27     Watercolor
# 2145  ART-02146  NeoSurrealist  Impressionism    2024-03-29       3D Model
# 6268  ART-06269     MidJourney         Cubism    2023-08-02  Pencil Sketch
# 7131  ART-07132        Vincent       Abstract    2023-06-29            Ink
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 909    DeepDream             50.85  South America    Abstract      Tumblr
# 1833  ArtBreeder             51.17           Asia       Urban  DeviantArt
# 6632  MidJourney             51.20         Europe       Urban   Pinterest
# 7673    GANPaint             51.74           Asia       Urban   Instagram
# 7472  MidJourney             51.94         Europe   Landscape  DeviantArt
# 3840  ArtBreeder             52.24  South America  Still Life   Pinterest
# 7232    GANPaint             52.76        Oceania    Abstract    Dribbble
# 2145    GANPaint             53.11         Europe    Abstract  DeviantArt
# 6268  MidJourney             53.28         Europe    Portrait      Tumblr
# 7131  ArtBreeder             54.93        Oceania      Sci-Fi   Pinterest
#
#                                             Description  \
# 909   A mesmerizing piece of art that blends traditi...
# 1833  A mesmerizing piece of art that blends traditi...
# 6632  A mesmerizing piece of art that blends traditi...
# 7673  A mesmerizing piece of art that blends traditi...
# 7472  A mesmerizing piece of art that blends traditi...
# 3840  A mesmerizing piece of art that blends traditi...
# 7232  A mesmerizing piece of art that blends traditi...
# 2145  A mesmerizing piece of art that blends traditi...
# 6268  A mesmerizing piece of art that blends traditi...
# 7131  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 909   https://example.com/artwork/00910.jpg
# 1833  https://example.com/artwork/01834.jpg
# 6632  https://example.com/artwork/06633.jpg
# 7673  https://example.com/artwork/07674.jpg
# 7472  https://example.com/artwork/07473.jpg
# 3840  https://example.com/artwork/03841.jpg
# 7232  https://example.com/artwork/07233.jpg
# 2145  https://example.com/artwork/02146.jpg
# 6268  https://example.com/artwork/06269.jpg
# 7131  https://example.com/artwork/07132.jpg

# %% [markdown]
# ### 7.Group the artworks by "Artist_Name" and calculate the average "Popularity_Score" for each artist.

# %%
df.groupby('Artist_Name')['Popularity_Score'].mean()
# Out:
# Artist_Name
# AIArtist123         2402.990198
# AbstractoBot        2438.509925
# ArtBreeder          2418.609719
# DALL-E              2490.125094
# DaVinciNet          2558.465712
# DeepArt             2591.649838
# DeepDream           2498.119969
# GANPaint            2549.093847
# GenerativeGenius    2566.583829
# MidJourney          2471.910375
# MonaBot             2487.533201
# NeoSurrealist       2480.058879
# PicassoAI           2510.702214
# RenoirBot           2598.548453
# Vincent             2563.740516
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 8.Group the data by "Art_Style" and count the number of artworks in each style.

# %%
df.groupby('Art_Style')['Artwork_ID'].count()
# Out:
# Art_Style
# Abstract          949
# Conceptual        969
# Cubism           1050
# Expressionism    1021
# Futurism         1016
# Impressionism     996
# Minimalism        995
# Pop Art          1008
# Realism          1022
# Surrealism        974
# Name: Artwork_ID, dtype: int64

# %% [markdown]
# ### 9.How many artworks were created using each medium?

# %%
df.groupby('Medium')['Artwork_ID'].size()
# Out:
# Medium
# 3D Model          958
# Acrylic Paint    1025
# Charcoal          983
# Collage           998
# Digital           999
# Ink               959
# Mixed Media      1041
# Oil Paint         979
# Pencil Sketch    1048
# Watercolor       1010
# Name: Artwork_ID, dtype: int64

# %% [markdown]
# ### 10.Check for any missing values in the dataset.

# %%
df.isna().sum()
# Out:
# Artwork_ID          0
# Artist_Name         0
# Art_Style           0
# Creation_Date       0
# Medium              0
# Tools_Used          0
# Popularity_Score    0
# Region              0
# Art_Genre           0
# Platform            0
# Description         0
# Image_URL           0
# dtype: int64

# %% [markdown]
# ### 11.Calculate the standard deviation of the "Popularity_Score" for each "Art_Style".

# %%
df.groupby('Art_Style')['Popularity_Score'].std()
# Out:
# Art_Style
# Abstract         1457.836653
# Conceptual       1426.173350
# Cubism           1451.142056
# Expressionism    1465.789492
# Futurism         1422.966785
# Impressionism    1391.974547
# Minimalism       1434.589041
# Pop Art          1435.627543
# Realism          1411.020359
# Surrealism       1409.886662
# Name: Popularity_Score, dtype: float64

# %% [markdown]
# ### 12.Calculate the mean, median, and standard deviation of the "Popularity_Score" for artworks created using "GANPaint"

# %%
Gan=df[df['Tools_Used']=='GANPaint']

# %%
Gan['Popularity_Score'].mean()
# Out:
# 2524.002265084075

# %%
Gan['Popularity_Score'].median()
# Out:
# 2483.72

# %%
Gan['Popularity_Score'].std()
# Out:
# 1424.8634558905715

# %% [markdown]
# ### 13.Count the number of artworks created by each artist

# %%
df.groupby('Artist_Name')['Artwork_ID'].count()
# Out:
# Artist_Name
# AIArtist123         657
# AbstractoBot        665
# ArtBreeder          675
# DALL-E              691
# DaVinciNet          681
# DeepArt             678
# DeepDream           649
# GANPaint            668
# GenerativeGenius    619
# MidJourney          694
# MonaBot             656
# NeoSurrealist       678
# PicassoAI           664
# RenoirBot           666
# Vincent             659
# Name: Artwork_ID, dtype: int64

# %%
df
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 0     ART-00001            DALL-E     Conceptual    2023-03-11        Collage
# 1     ART-00002      AbstractoBot       Futurism    2022-11-27      Oil Paint
# 2     ART-00003           Vincent       Futurism    2024-03-13       Charcoal
# 3     ART-00004        ArtBreeder  Impressionism    2022-09-12  Pencil Sketch
# 4     ART-00005            DALL-E     Surrealism    2022-12-05        Collage
# ...         ...               ...            ...           ...            ...
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22      Oil Paint
# 9996  ART-09997         RenoirBot        Pop Art    2023-04-05  Acrylic Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
# 9998  ART-09999  GenerativeGenius         Cubism    2022-10-04  Acrylic Paint
# 9999  ART-10000  GenerativeGenius       Abstract    2022-12-07  Pencil Sketch
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 0       GANPaint           1604.25  South America       Urban   Instagram
# 1     MidJourney           4162.12  North America    Abstract    Dribbble
# 2       GANPaint           2989.38         Europe   Mythology      Reddit
# 3     ArtBreeder           2985.97         Europe  Still Life      Tumblr
# 4      DeepDream           2035.18           Asia  Conceptual  DeviantArt
# ...          ...               ...            ...         ...         ...
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
# 9996    GANPaint           4715.45        Oceania   Landscape   Instagram
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
# 9998    GANPaint           2229.60         Africa    Portrait  DeviantArt
# 9999   DeepDream           3815.99           Asia       Urban     Twitter
#
#                                             Description  \
# 0     A mesmerizing piece of art that blends traditi...
# 1     A mesmerizing piece of art that blends traditi...
# 2     A mesmerizing piece of art that blends traditi...
# 3     A mesmerizing piece of art that blends traditi...
# 4     A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9995  A mesmerizing piece of art that blends traditi...
# 9996  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
# 9998  A mesmerizing piece of art that blends traditi...
# 9999  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL
# 0     https://example.com/artwork/00001.jpg
# 1     https://example.com/artwork/00002.jpg
# 2     https://example.com/artwork/00003.jpg
# 3     https://example.com/artwork/00004.jpg
# 4     https://example.com/artwork/00005.jpg
# ...                                     ...
# 9995  https://example.com/artwork/09996.jpg
# 9996  https://example.com/artwork/09997.jpg
# 9997  https://example.com/artwork/09998.jpg
# 9998  https://example.com/artwork/09999.jpg
# 9999  https://example.com/artwork/10000.jpg
#
# [10000 rows x 12 columns]

# %% [markdown]
# ### 14.Filter the dataset to show only artworks created in "2024" using "Oil Paint".

# %%
df['Creation_Date'] = pd.to_datetime(df['Creation_Date'])
df['year'] = df['Creation_Date'].dt.year

# %%
df[(df['year'] == 2024) & (df['Medium'] == 'Oil Paint')]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date     Medium  \
# 43    ART-00044         DeepDream       Futurism    2024-07-26  Oil Paint
# 126   ART-00127  GenerativeGenius  Impressionism    2024-01-06  Oil Paint
# 146   ART-00147           MonaBot     Minimalism    2024-05-25  Oil Paint
# 168   ART-00169           MonaBot        Pop Art    2024-05-20  Oil Paint
# 207   ART-00208        MidJourney     Minimalism    2024-01-14  Oil Paint
# ...         ...               ...            ...           ...        ...
# 9843  ART-09844       AIArtist123  Expressionism    2024-06-16  Oil Paint
# 9914  ART-09915      AbstractoBot  Impressionism    2024-01-14  Oil Paint
# 9990  ART-09991            DALL-E     Minimalism    2024-08-15  Oil Paint
# 9992  ART-09993         RenoirBot       Futurism    2024-04-04  Oil Paint
# 9995  ART-09996         RenoirBot     Conceptual    2024-01-22  Oil Paint
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 43     DeepDream           4048.81         Africa   Mythology     Behance
# 126   MidJourney           1042.80         Europe      Nature      Reddit
# 146     GANPaint           2736.10         Africa    Portrait     Behance
# 168   ArtBreeder           3305.86         Africa      Nature     Behance
# 207     GANPaint           4860.01  South America   Landscape      Reddit
# ...          ...               ...            ...         ...         ...
# 9843   DeepDream            944.81  North America    Portrait     Twitter
# 9914  ArtBreeder           1184.63  North America  Still Life     Behance
# 9990  MidJourney            574.55           Asia    Abstract   Pinterest
# 9992   DeepDream            385.71           Asia       Urban      Reddit
# 9995    GANPaint           3886.42        Oceania      Nature  DeviantArt
#
#                                             Description  \
# 43    A mesmerizing piece of art that blends traditi...
# 126   A mesmerizing piece of art that blends traditi...
# 146   A mesmerizing piece of art that blends traditi...
# 168   A mesmerizing piece of art that blends traditi...
# 207   A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9843  A mesmerizing piece of art that blends traditi...
# 9914  A mesmerizing piece of art that blends traditi...
# 9990  A mesmerizing piece of art that blends traditi...
# 9992  A mesmerizing piece of art that blends traditi...
# 9995  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL  year
# 43    https://example.com/artwork/00044.jpg  2024
# 126   https://example.com/artwork/00127.jpg  2024
# 146   https://example.com/artwork/00147.jpg  2024
# 168   https://example.com/artwork/00169.jpg  2024
# 207   https://example.com/artwork/00208.jpg  2024
# ...                                     ...   ...
# 9843  https://example.com/artwork/09844.jpg  2024
# 9914  https://example.com/artwork/09915.jpg  2024
# 9990  https://example.com/artwork/09991.jpg  2024
# 9992  https://example.com/artwork/09993.jpg  2024
# 9995  https://example.com/artwork/09996.jpg  2024
#
# [351 rows x 13 columns]

# %% [markdown]
# ### 15.Display all artworks that are either "Futurism" or "Impressionism" and have a "Popularity_Score" below 2000.

# %%
df[((df['Art_Style'] == 'Futurism') | (df['Art_Style'] == 'Impressionism')) & (df['Popularity_Score'] < 2000)]
# Out:
#      Artwork_ID       Artist_Name      Art_Style Creation_Date         Medium  \
# 9     ART-00010        DaVinciNet  Impressionism    2023-09-13     Watercolor
# 29    ART-00030  GenerativeGenius       Futurism    2023-04-20  Acrylic Paint
# 36    ART-00037        MidJourney  Impressionism    2023-10-22        Collage
# 44    ART-00045         RenoirBot       Futurism    2023-10-07     Watercolor
# 49    ART-00050         RenoirBot       Futurism    2023-05-24        Collage
# ...         ...               ...            ...           ...            ...
# 9966  ART-09967            DALL-E  Impressionism    2023-03-15        Digital
# 9984  ART-09985         DeepDream  Impressionism    2023-04-17       3D Model
# 9986  ART-09987         PicassoAI       Futurism    2024-02-16  Pencil Sketch
# 9992  ART-09993         RenoirBot       Futurism    2024-04-04      Oil Paint
# 9997  ART-09998        ArtBreeder       Futurism    2023-01-27       3D Model
#
#       Tools_Used  Popularity_Score         Region   Art_Genre    Platform  \
# 9         DALL-E           1188.63  North America    Abstract     Twitter
# 29    ArtBreeder            873.77           Asia  Conceptual   Pinterest
# 36      GANPaint           1833.19         Europe  Conceptual   Pinterest
# 44        DALL-E           1948.95        Oceania    Abstract      Reddit
# 49        DALL-E            281.43  North America    Portrait  ArtStation
# ...          ...               ...            ...         ...         ...
# 9966    GANPaint            880.38         Europe       Urban      Flickr
# 9984  ArtBreeder            892.33         Europe       Urban  DeviantArt
# 9986   DeepDream           1722.87           Asia  Still Life     Twitter
# 9992   DeepDream            385.71           Asia       Urban      Reddit
# 9997   DeepDream            741.83         Europe  Conceptual     Behance
#
#                                             Description  \
# 9     A mesmerizing piece of art that blends traditi...
# 29    A mesmerizing piece of art that blends traditi...
# 36    A mesmerizing piece of art that blends traditi...
# 44    A mesmerizing piece of art that blends traditi...
# 49    A mesmerizing piece of art that blends traditi...
# ...                                                 ...
# 9966  A mesmerizing piece of art that blends traditi...
# 9984  A mesmerizing piece of art that blends traditi...
# 9986  A mesmerizing piece of art that blends traditi...
# 9992  A mesmerizing piece of art that blends traditi...
# 9997  A mesmerizing piece of art that blends traditi...
#
#                                   Image_URL  year
# 9     https://example.com/artwork/00010.jpg  2023
# 29    https://example.com/artwork/00030.jpg  2023
# 36    https://example.com/artwork/00037.jpg  2023
# 44    https://example.com/artwork/00045.jpg  2023
# 49    https://example.com/artwork/00050.jpg  2023
# ...                                     ...   ...
# 9966  https://example.com/artwork/09967.jpg  2023
# 9984  https://example.com/artwork/09985.jpg  2023
# 9986  https://example.com/artwork/09987.jpg  2024
# 9992  https://example.com/artwork/09993.jpg  2024
# 9997  https://example.com/artwork/09998.jpg  2023
#
# [796 rows x 13 columns]

# %% [markdown]
# ### 16.What is the most popular artwork (highest Popularity_Score)?

# %%
df['Popularity_Score'].max()
# Out:
# 4999.62

# %% [markdown]
# ### 17.What is the least popular artwork (lowest Popularity_Score)?

# %%
df['Popularity_Score'].min()
# Out:
# 50.85

# %% [markdown]
# ### 18.What is the most common art genre in Europe?

# %%
europe=df[df['Region'] == 'Europe']
europe['Art_Genre'].value_counts().idxmax()
# Out:
# 'Portrait'

# %% [markdown]
# ### 19.Export the dataset to a CSV file named "artwork_data.csv".

# %%
df2=df.to_csv('artwork_data.csv', index=False)

# %% [markdown]
# ### 20.Group the data by Artist_Name and calculate the total number of artworks created by each artist.

# %%
df.groupby('Artist_Name')['Artwork_ID'].count()
# Out:
# Artist_Name
# AIArtist123         657
# AbstractoBot        665
# ArtBreeder          675
# DALL-E              691
# DaVinciNet          681
# DeepArt             678
# DeepDream           649
# GANPaint            668
# GenerativeGenius    619
# MidJourney          694
# MonaBot             656
# NeoSurrealist       678
# PicassoAI           664
# RenoirBot           666
# Vincent             659
# Name: Artwork_ID, dtype: int64
